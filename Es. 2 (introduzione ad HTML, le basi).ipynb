# %% [markdown]
# # LE BASI DELL'HTML

# %%
<!DOCTYPE html>
<html>
<head>
    <!--Metadati, collegamenti ai fogli di stile, ecc... vanno qui-->  
    <title>Hello world</title>
</head>
<body>
    <!--I contenuti visbili nella pagine va qui-->
    <h1>Questo è il mio primo titolo principale</h1>
    <p>Questo è il mio primo paragrafo di testo</p>
</body>
</html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <!--Metadati, collegamenti ai fogli di stile, ecc... vanno qui-->
#     <title>Hello world</title>
# </head>
# <body>
#     <!--I contenuti visbili nella pagine va qui-->
#     <h1>Questo è il mio primo titolo principale</h1>
#     <p>Questo è il mio primo paragrafo di testo</p>
# </body>
# </html>

# %% [markdown]
# # LE LISTE PUNTATE E NUMERATE

# %%
<!DOCTYPE html>
<html>
<head>
    <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->  
    <title>Il mio titolo</title>
</head>
<body>
    <!--Contenuto visibile dalla pagine va qui-->
    <h1>Il mio titolo principale</h1>
    <p>Questo è il mio paragrafo di testo</p>
    <h2>Ecco la lista ad elenco puntato di esempio:</h2>
    <ul><!--È l'acronimo di Unordered List-->
        <li>Elemento 1</li>
        <li>Elemento 2</li>
    </ul>
    <h2>Ecco la lista ad elenco numerato di esempio:</h2>
    <ol><!--È l'acronimo di Ordered List-->
        <li>Esempio 1</li>
        <li>Esempio 2</li>
    </ol>
</body>
</html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->
#     <title>Il mio titolo</title>
# </head>
# <body>
#     <!--Contenuto visibile dalla pagine va qui-->
#     <h1>Il mio titolo principale</h1>
#     <p>Questo è il mio paragrafo di testo</p>
#     <h2>Ecco la lista ad elenco puntato di esempio:</h2>
#     <ul><!--È l'acronimo di Undefinited list-->
#         <li>Elemento 1</li>
#         <li>Elemento 2</li>
#     </ul>
#     <h2>Ecco la lista ad elenco numerato di esempio:</h2>
#     <ol><!--È l'acronimo di ??? list-->
#         <li>Esempio 1</li>
#         <li>Esempio 2</li>
#     </ol>
# </body>
# </html>

# %% [markdown]
# # I COLLEGAMENTI WEB

# %%
<!DOCTYPE html>
<html>
<head>
    <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->  
    <title>Il mio titolo</title>
</head>
<body>
    <!--Contenuto visibile dalla pagine va qui-->
    <h1>Il mio titolo principale</h1>
    <p>Questo è il mio paragrafo di testo</p>
    <h2>Ecco la lista ad elenco puntato di esempio:</h2>
    <ul><!--È l'acronimo di Unordered List-->
        <li>Elemento 1</li>
        <li>Elemento 2</li>
    </ul>
    <h2>Ecco la lista ad elenco numerato di esempio:</h2>
    <ol><!--È l'acronimo di Ordered List-->
        <li>Esempio 1</li>
        <li>Esempio 2</li>
    </ol>
    <h2>Ecco la lista dei collegamenti di esempio (senza reindirizzamento):</h2><!--In questo caso bisogna cliccare sopra il link per vedere il sito-->
    <a href="https://www.istitutofreud.it">Sito ufficiale dell'Istituto Freud</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
    <a href="https://it.wikipedia.org/wiki/Pagina_principale">Sito ufficiale di Wikipedia</a><br>
    <a href="https://stackoverflow.com/">Sito ufficiale di Stack Overflow</a><br>
</body>
</html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->
#     <title>Il mio titolo</title>
# </head>
# <body>
#     <!--Contenuto visibile dalla pagine va qui-->
#     <h1>Il mio titolo principale</h1>
#     <p>Questo è il mio paragrafo di testo</p>
#     <h2>Ecco la lista ad elenco puntato di esempio:</h2>
#     <ul><!--È l'acronimo di Unordered List-->
#         <li>Elemento 1</li>
#         <li>Elemento 2</li>
#     </ul>
#     <h2>Ecco la lista ad elenco numerato di esempio:</h2>
#     <ol><!--È l'acronimo di Ordered List-->
#         <li>Esempio 1</li>
#         <li>Esempio 2</li>
#     </ol>
#     <h2>Ecco la lista dei collegamenti di esempio (senza reindirizzamento):</h2><!--In questo caso bisogna cliccare sopra il link per vedere il sito-->
#     <a href="https://www.istitutofreud.it">Sito ufficiale dell'Istituto Freud</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
#     <a href="https://it.wikipedia.org/wiki/Pagina_principale">Sito ufficiale di Wikipedia</a><br>
#     <a href="https://stackoverflow.com/">Sito ufficiale di Stack Overflow</a><br>
# </body>
# </html>

# %%
<!DOCTYPE html>
<html>
<head>
    <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->  
    <title>Il mio titolo</title>
</head>
<body>
    <!--Contenuto visibile dalla pagine va qui-->
    <h1>Il mio titolo principale</h1>
    <p>Questo è il mio paragrafo di testo</p>
    <h2>Ecco la lista ad elenco puntato di esempio:</h2>
    <ul><!--È l'acronimo di Unordered List-->
        <li>Elemento 1</li>
        <li>Elemento 2</li>
    </ul>
    <h2>Ecco la lista ad elenco numerato di esempio:</h2>
    <ol><!--È l'acronimo di Ordered List-->
        <li>Esempio 1</li>
        <li>Esempio 2</li>
    </ol>
    <h2>Ecco la lista dei collegamenti di esempio (con indirizzamento):</h2><!--In questo caso bisogna cliccare sopra il link per vedere il sito, attraverso il comando target "blank" è possibile far aprire il sito in una altra scheda. In altre parole blank indica che il link deve essere visualizzato in uno spazio vuoto o bianco del browser, anziché sostituire il contenuto della finestra corrente.-->
    <a href="https://www.istitutofreud.it" target="_blank">Sito ufficiale dell'Istituto Freud</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
    <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">Sito ufficiale di Wikipedia</a><br>
    <a href="https://stackoverflow.com/" target="_blank">Sito ufficiale di Stack Overflow</a><br>
</body>
</html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->
#     <title>Il mio titolo</title>
# </head>
# <body>
#     <!--Contenuto visibile dalla pagine va qui-->
#     <h1>Il mio titolo principale</h1>
#     <p>Questo è il mio paragrafo di testo</p>
#     <h2>Ecco la lista ad elenco puntato di esempio:</h2>
#     <ul><!--È l'acronimo di Unordered List-->
#         <li>Elemento 1</li>
#         <li>Elemento 2</li>
#     </ul>
#     <h2>Ecco la lista ad elenco numerato di esempio:</h2>
#     <ol><!--È l'acronimo di Ordered List-->
#         <li>Esempio 1</li>
#         <li>Esempio 2</li>
#     </ol>
#     <h2>Ecco la lista dei collegamenti di esempio (con indirizzamento):</h2><!--In questo caso bisogna cliccare sopra il link per vedere il sito, attraverso il comando target "blank" è possibile far aprire il sito in una altra scheda. In altre parole blank indica che il link deve essere visualizzato in uno spazio vuoto o bianco del browser, anziché sostituire il contenuto della finestra corrente.-->
#     <a href="https://www.istitutofreud.it" target="_blank">Sito ufficiale dell'Istituto Freud</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
#     <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">Sito ufficiale di Wikipedia</a><br>
#     <a href="https://stackoverflow.com/" target="_blank">Sito ufficiale di Stack Overflow</a><br>
# </body>
# </html>

# %%
<!DOCTYPE html>
<html>
<head>
    <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->  
    <title>Il mio titolo</title>
</head>
<body>
    <!--Contenuto visibile dalla pagine va qui-->
    <h1>Il mio titolo principale</h1>
    <p>Questo è il mio paragrafo di testo</p>
    <h2>Ecco la lista ad elenco puntato di esempio:</h2>
    <ul><!--È l'acronimo di Unordered List-->
        <li>Elemento 1</li>
        <li>Elemento 2</li>
    </ul>
    <h2>Ecco la lista ad elenco numerato di esempio:</h2>
    <ol><!--È l'acronimo di Ordered List-->
        <li>Esempio 1</li>
        <li>Esempio 2</li>
    </ol>
    <h2>Ecco la lista dei collegamenti di esempio (mostrando i link senza indirizzamento):</h2><!--Senza il target-->
    <a href="https://www.istitutofreud.it">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
    <a href="https://it.wikipedia.org/wiki/Pagina_principale">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
    <a href="https://stackoverflow.com/">https://stackoverflow.com/</a><br>
</body>
</html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->
#     <title>Il mio titolo</title>
# </head>
# <body>
#     <!--Contenuto visibile dalla pagine va qui-->
#     <h1>Il mio titolo principale</h1>
#     <p>Questo è il mio paragrafo di testo</p>
#     <h2>Ecco la lista ad elenco puntato di esempio:</h2>
#     <ul><!--È l'acronimo di Unordered List-->
#         <li>Elemento 1</li>
#         <li>Elemento 2</li>
#     </ul>
#     <h2>Ecco la lista ad elenco numerato di esempio:</h2>
#     <ol><!--È l'acronimo di Ordered List-->
#         <li>Esempio 1</li>
#         <li>Esempio 2</li>
#     </ol>
#     <h2>Ecco la lista dei collegamenti di esempio (mostrando i link senza indirizzamento):</h2><!--Senza il target-->
#     <a href="https://www.istitutofreud.it">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
#     <a href="https://it.wikipedia.org/wiki/Pagina_principale">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
#     <a href="https://stackoverflow.com/">https://stackoverflow.com/</a><br>
# </body>
# </html>

# %%
<!DOCTYPE html>
<html>
<head>
    <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->  
    <title>Il mio titolo</title>
</head>
<body>
    <!--Contenuto visibile dalla pagine va qui-->
    <h1>Il mio titolo principale</h1>
    <p>Questo è il mio paragrafo di testo</p>
    <h2>Ecco la lista ad elenco puntato di esempio:</h2>
    <ul><!--È l'acronimo di Unordered List-->
        <li>Elemento 1</li>
        <li>Elemento 2</li>
    </ul>
    <h2>Ecco la lista ad elenco numerato di esempio:</h2>
    <ol><!--È l'acronimo di Ordered List-->
        <li>Esempio 1</li>
        <li>Esempio 2</li>
    </ol>
    <h2>Ecco la lista dei collegamenti di esempio (mostrando i link con indirizzamento):</h2><!--Con il target-->
    <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
    <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
    <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
</body>
</html>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->
#     <title>Il mio titolo</title>
# </head>
# <body>
#     <!--Contenuto visibile dalla pagine va qui-->
#     <h1>Il mio titolo principale</h1>
#     <p>Questo è il mio paragrafo di testo</p>
#     <h2>Ecco la lista ad elenco puntato di esempio:</h2>
#     <ul><!--È l'acronimo di Unordered List-->
#         <li>Elemento 1</li>
#         <li>Elemento 2</li>
#     </ul>
#     <h2>Ecco la lista ad elenco numerato di esempio:</h2>
#     <ol><!--È l'acronimo di Ordered List-->
#         <li>Esempio 1</li>
#         <li>Esempio 2</li>
#     </ol>
#     <h2>Ecco la lista dei collegamenti di esempio (mostrando i link con indirizzamento):</h2><!--Con il target-->
#     <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
#     <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
#     <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
# </body>
# </html>

# %% [markdown]
# # LE IMMAGINI DAL WEB E DAL COMPUTER LOCALE

# %%
<!DOCTYPE html>
<html>
<head>
    <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->  
    <title>Il mio titolo</title>
</head>
<body>
    <!--Contenuto visibile dalla pagine va qui-->
    <h1>Il mio titolo principale</h1>
    <p>Questo è il mio paragrafo di testo</p>
    <h2>Ecco la lista ad elenco puntato di esempio:</h2>
    <ul><!--È l'acronimo di Unordered List-->
        <li>Elemento 1</li>
        <li>Elemento 2</li>
    </ul>
    <h2>Ecco la lista ad elenco numerato di esempio:</h2>
    <ol><!--È l'acronimo di Ordered List-->
        <li>Esempio 1</li>
        <li>Esempio 2</li>
    </ol>
    <h2>Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
    <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
    <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
    <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
</body>
</html>
    <h2>Ecco un immagine presa dal web di esempio:</h2>
<img src="https://www.google.com/images/branding/googlelogo/1x/googlelogo_color_272x92dp.png" alt="Logo di Google" width="272" height="92">
<!--src: Specifica il percorso dell'immagine web
alt: Fornisce una descrizione testuale alternativa all'immagine, utile per l'accessibilità e visualizzata se l'immagine non può essere caricata.
width: Imposta la larghezza dell'immagine in pixel.
height: Imposta l'altezza dell'immagine in pixel.-->

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->
#     <title>Il mio titolo</title>
# </head>
# <body>
#     <!--Contenuto visibile dalla pagine va qui-->
#     <h1>Il mio titolo principale</h1>
#     <p>Questo è il mio paragrafo di testo</p>
#     <h2>Ecco la lista ad elenco puntato di esempio:</h2>
#     <ul><!--È l'acronimo di Unordered List-->
#         <li>Elemento 1</li>
#         <li>Elemento 2</li>
#     </ul>
#     <h2>Ecco la lista ad elenco numerato di esempio:</h2>
#     <ol><!--È l'acronimo di Ordered List-->
#         <li>Esempio 1</li>
#         <li>Esempio 2</li>
#     </ol>
#     <h2>Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
#     <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
#     <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
#     <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
# </body>
# </html>
#     <h2>Ecco un immagine presa dal web di esempio:</h2>
# <img src="https://www.google.com/images/branding/googlelogo/1x/googlelogo_color_272x92dp.png" alt="Logo di Google" width="272" height="92">
# <!--src: Specifica il percorso dell'immagine web
# alt: Fornisce una descrizione testuale alternativa all'immagine, utile per l'accessibilità e visualizzata se l'immagine non può essere caricata.
# width: Imposta la larghezza dell'immagine in pixel.
# height: Imposta l'altezza dell'immagine in pixel.-->

# %%
<!DOCTYPE html>
<html>
<head>
    <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->  
    <title>Il mio titolo</title>
</head>
<body>
    <!--Contenuto visibile dalla pagine va qui-->
    <h1>Il mio titolo principale</h1>
    <p>Questo è il mio paragrafo di testo</p>
    <h2>Ecco la lista ad elenco puntato di esempio:</h2>
    <ul><!--È l'acronimo di Unordered List-->
        <li>Elemento 1</li>
        <li>Elemento 2</li>
    </ul>
    <h2>Ecco la lista ad elenco numerato di esempio:</h2>
    <ol><!--È l'acronimo di Ordered List-->
        <li>Esempio 1</li>
        <li>Esempio 2</li>
    </ol>
    <h2>Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
    <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
    <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
    <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
</body>
</html>
<h2>Ecco una immagine inserita dal disco locale selezionando la PATH (pultroppo Jupyter non riesce a caricarla, tuttavia si vede la didascalia):</h2>
<img src="file:///C:\Users\matte\Downloads\R.jpeg" alt="La mia immagine di prova" width="200" height="150"><!--ho scritto la Path di dove si trova il file poichè non era nella stessa cartella del notebook-->

# %% [markdown]
# # <!DOCTYPE html>
# <html>
# <head>
#     <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->
#     <title>Il mio titolo</title>
# </head>
# <body>
#     <!--Contenuto visibile dalla pagine va qui-->
#     <h1>Il mio titolo principale</h1>
#     <p>Questo è il mio paragrafo di testo</p>
#     <h2>Ecco la lista ad elenco puntato di esempio:</h2>
#     <ul><!--È l'acronimo di Unordered List-->
#         <li>Elemento 1</li>
#         <li>Elemento 2</li>
#     </ul>
#     <h2>Ecco la lista ad elenco numerato di esempio:</h2>
#     <ol><!--È l'acronimo di Ordered List-->
#         <li>Esempio 1</li>
#         <li>Esempio 2</li>
#     </ol>
#     <h2>Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
#     <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
#     <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
#     <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
# </body>
# </html>
# <h2>Ecco una immagine inserita dal disco locale selezionando la PATH (pultroppo Jupyter non riesce a caricarla perchè non ha accesso a i miei file, tuttavia si vede la didascalia):</h2>
# <img src="file:///C:/Users/matte/Downloads/R.jpeg" alt="La mia immagine di prova" width="200" height="150"><!--ho scritto la Path di dove si trova il file poichè non era nella stessa cartella del notebook-->

# %%
<!DOCTYPE html>
<html>
<head>
    <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->  
    <title>Il mio titolo</title>
</head>
<body>
    <!--Contenuto visibile dalla pagine va qui-->
    <h1>Il mio titolo principale</h1>
    <p>Questo è il mio paragrafo di testo</p>
    <h2>Ecco la lista ad elenco puntato di esempio:</h2>
    <ul><!--È l'acronimo di Unordered List-->
        <li>Elemento 1</li>
        <li>Elemento 2</li>
    </ul>
    <h2>Ecco la lista ad elenco numerato di esempio:</h2>
    <ol><!--È l'acronimo di Ordered List-->
        <li>Esempio 1</li>
        <li>Esempio 2</li>
    </ol>
    <h2>Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
    <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
    <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
    <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
</body>
</html>
<h2>Ecco una immagine inserita dal disco locale senza selezionare la PATH perchè si trova nella stessa cartella (così funziona):</h2>
<img src="R.jpeg" alt="La tua immagine" width="200" height="150"><!--ho scritto direttamente il nome del file senza indicare la PATH perchè essendo dentro la stessa cartella del notebook, inserendo il nome la trova immediatamente-->

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->
#     <title>Il mio titolo</title>
# </head>
# <body>
#     <!--Contenuto visibile dalla pagine va qui-->
#     <h1>Il mio titolo principale</h1>
#     <p>Questo è il mio paragrafo di testo</p>
#     <h2>Ecco la lista ad elenco puntato di esempio:</h2>
#     <ul><!--È l'acronimo di Unordered List-->
#         <li>Elemento 1</li>
#         <li>Elemento 2</li>
#     </ul>
#     <h2>Ecco la lista ad elenco numerato di esempio:</h2>
#     <ol><!--È l'acronimo di Ordered List-->
#         <li>Esempio 1</li>
#         <li>Esempio 2</li>
#     </ol>
#     <h2>Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
#     <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
#     <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
#     <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
# </body>
# </html>
# <h2>Ecco una immagine inserita dal disco locale senza selezionare la PATH perchè si trova nella stessa cartella (così funziona):</h2>
# <img src="R.jpeg" alt="La tua immagine" width="200" height="150"><!--ho scritto direttamente il nome del file senza indicare la PATH perchè essendo dentro la stessa cartella del notebook, inserendo il nome la trova immediatamente-->

# %% [markdown]
# # LE IMPOSTAZIONI GRAFICHE

# %%
<!DOCTYPE html>
<html>
<head>
    <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->  
    <title>Il mio titolo</title>
</head>
<body>
    <!--Contenuto visibile dalla pagine va qui-->
    <h1>Il mio titolo principale</h1>
    <p style="color: red; font-size:30px;">Questo è il mio paragrafo di testo colorato di rosso<!--con style setto le impostazioni dello stile grafico di una qualsiasi intestazione e sarebbe un comando CSS-->
    <p>Questo è il mio paragrafo di testo</p>
    <h2>Ecco la lista ad elenco puntato di esempio:</h2>
    <ul><!--È l'acronimo di Unordered List-->
        <li>Elemento 1</li>
        <li>Elemento 2</li>
    </ul>
    <h2>Ecco la lista ad elenco numerato di esempio:</h2>
    <ol><!--È l'acronimo di Ordered List-->
        <li>Esempio 1</li>
        <li>Esempio 2</li>
    </ol>
    <h2>Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
    <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
    <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
    <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
</body>
</html>
<h2>Ecco una immagine inserita dal disco locale senza selezionare la PATH perchè si trova nella stessa cartella (così funziona):</h2>
<img src="R.jpeg" alt="La tua immagine" width="200" height="150"><!--ho scritto direttamente il nome del file senza indicare la PATH perchè essendo dentro la stessa cartella del notebook, inserendo il nome la trova immediatamente-->

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->
#     <title>Il mio titolo</title>
# </head>
# <body>
#     <!--Contenuto visibile dalla pagine va qui-->
#     <h1>Il mio titolo principale</h1>
#     <p style="color: red; font-size:30px;">Questo è il mio paragrafo di testo colorato di rosso<!--con style setto le impostazioni dello stile grafico di una qualsiasi intestazione e sarebbe un comando CSS-->
#     <p>Questo è il mio paragrafo di testo</p>
#     <h2>Ecco la lista ad elenco puntato di esempio:</h2>
#     <ul><!--È l'acronimo di Unordered List-->
#         <li>Elemento 1</li>
#         <li>Elemento 2</li>
#     </ul>
#     <h2>Ecco la lista ad elenco numerato di esempio:</h2>
#     <ol><!--È l'acronimo di Ordered List-->
#         <li>Esempio 1</li>
#         <li>Esempio 2</li>
#     </ol>
#     <h2>Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
#     <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
#     <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
#     <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
# </body>
# </html>
# <h2>Ecco una immagine inserita dal disco locale senza selezionare la PATH perchè si trova nella stessa cartella (così funziona):</h2>
# <img src="R.jpeg" alt="La tua immagine" width="200" height="150"><!--ho scritto direttamente il nome del file senza indicare la PATH perchè essendo dentro la stessa cartella del notebook, inserendo il nome la trova immediatamente-->

# %%
<!DOCTYPE html>
<html>
<head>
    <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->  
    <title>Il mio titolo</title>
</head>
<body style="background-color:tomato;"><!--con background inserisco uno sfondo in tutta la pagina perchè l'ho inserito in body però su Jupyter non funziona perchè non lo supporta-->
    <h1>Il mio titolo principale</h1>
    <p style="color: red; font-size:30px;">Questo è il mio paragrafo di testo colorato di rosso<!--con style setto le impostazioni dello stile grafico di una qualsiasi intestazione e sarebbe un comando CSS-->
    <p>Questo è il mio paragrafo di testo</p>
    <h2>Ecco la lista ad elenco puntato di esempio:</h2>
    <ul><!--È l'acronimo di Unordered List-->
        <li>Elemento 1</li>
        <li>Elemento 2</li>
    </ul>
    <h2>Ecco la lista ad elenco numerato di esempio:</h2>
    <ol><!--È l'acronimo di Ordered List-->
        <li>Esempio 1</li>
        <li>Esempio 2</li>
    </ol>
    <h2>Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
    <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
    <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
    <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
</body>
</html>
<h2>Ecco una immagine inserita dal disco locale senza selezionare la PATH perchè si trova nella stessa cartella (così funziona):</h2>
<img src="R.jpeg" alt="La tua immagine" width="200" height="150"><!--ho scritto direttamente il nome del file senza indicare la PATH perchè essendo dentro la stessa cartella del notebook, inserendo il nome la trova immediatamente-->

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->
#     <title>Il mio titolo</title>
# </head>
# <body style="background-color:tomato;"><!--con background inserisco uno sfondo in tutta la pagina perchè l'ho inserito in body però su Jupyter non funziona perchè non lo supporta-->
#     <h1>Il mio titolo principale</h1>
#     <p style="color: red; font-size:30px;">Questo è il mio paragrafo di testo colorato di rosso<!--con style setto le impostazioni dello stile grafico di una qualsiasi intestazione e sarebbe un comando CSS-->
#     <p>Questo è il mio paragrafo di testo</p>
#     <h2>Ecco la lista ad elenco puntato di esempio:</h2>
#     <ul><!--È l'acronimo di Unordered List-->
#         <li>Elemento 1</li>
#         <li>Elemento 2</li>
#     </ul>
#     <h2>Ecco la lista ad elenco numerato di esempio:</h2>
#     <ol><!--È l'acronimo di Ordered List-->
#         <li>Esempio 1</li>
#         <li>Esempio 2</li>
#     </ol>
#     <h2>Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
#     <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
#     <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
#     <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
# </body>
# </html>
# <h2>Ecco una immagine inserita dal disco locale senza selezionare la PATH perchè si trova nella stessa cartella (così funziona):</h2>
# <img src="R.jpeg" alt="La tua immagine" width="200" height="150"><!--ho scritto direttamente il nome del file senza indicare la PATH perchè essendo dentro la stessa cartella del notebook, inserendo il nome la trova immediatamente-->

# %%
<!DOCTYPE html>
<html>
<head>
    <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->  
    <title>Il mio titolo</title>
</head>
<body style="background-color:powderblue;"><!--con background inserisco uno sfondo--!>
    <h1 style="background-color:lightgreen;"Il mio titolo principale</h1>
    <p style="background-color:tomato;""color: red; font-size:30px;"" font-family: Verdana, sans-serif;">Questo è il mio paragrafo di testo colorato di rosso<!--con style setto le impostazioni dello stile grafico di una qualsiasi intestazione e sarebbe un comando CSS-->
    <p>Questo è il mio paragrafo di testo</p>
    <h2>Ecco la lista ad elenco puntato di esempio:</h2>
    <ul><!--È l'acronimo di Unordered List-->
        <li>Elemento 1</li>
        <li>Elemento 2</li>
    </ul>
    <h2>Ecco la lista ad elenco numerato di esempio:</h2>
    <ol><!--È l'acronimo di Ordered List-->
        <li>Esempio 1</li>
        <li>Esempio 2</li>
    </ol>
    <h2 style="background-color:orange;">Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
    <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
    <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
    <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
</body>
</html>
<h2>Ecco una immagine inserita dal disco locale senza selezionare la PATH perchè si trova nella stessa cartella (così funziona):</h2>
<img src="R.jpeg" alt="La tua immagine" width="200" height="150"><!--ho scritto direttamente il nome del file senza indicare la PATH perchè essendo dentro la stessa cartella del notebook, inserendo il nome la trova immediatamente-->

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->
#     <title>Il mio titolo</title>
# </head>
# <body style="background-color:powderblue;"><!--con background inserisco uno sfondo--!>
#     <!--Contenuto visibile dalla pagine va qui-->
#     <h1 style="background-color:lightgreen;"Il mio titolo principale</h1>
#     <p style="background-color:tomato;""color: red; font-size:30px; font-family: Verdana, sans-serif;">Questo è il mio paragrafo di testo colorato di rosso<!--con style setto le impostazioni dello stile grafico di una qualsiasi intestazione e sarebbe un comando CSS-->
#     <p>Questo è il mio paragrafo di testo</p>
#     <h2>Ecco la lista ad elenco puntato di esempio:</h2>
#     <ul><!--È l'acronimo di Unordered List-->
#         <li>Elemento 1</li>
#         <li>Elemento 2</li>
#     </ul>
#     <h2>Ecco la lista ad elenco numerato di esempio:</h2>
#     <ol><!--È l'acronimo di Ordered List-->
#         <li>Esempio 1</li>
#         <li>Esempio 2</li>
#     </ol>
#     <h2 style="background-color:orange;">Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
#     <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
#     <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
#     <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
# </body>
# </html>
# <h2>Ecco una immagine inserita dal disco locale senza selezionare la PATH perchè si trova nella stessa cartella (così funziona):</h2>
# <img src="R.jpeg" alt="La tua immagine" width="200" height="150"><!--ho scritto direttamente il nome del file senza indicare la PATH perchè essendo dentro la stessa cartella del notebook, inserendo il nome la trova immediatamente-->

# %%
<!DOCTYPE html>
<html>
<head>
    <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->  
    <title>Il mio titolo</title>
</head>
<body style="background-color:powderblue;"><!--con background inserisco uno sfondo--!>
    <!--Contenuto visibile dalla pagine va qui-->
    <h1 style="background-color:lightgreen;"Il mio titolo principale</h1>
    <p style="background-color:tomato;""color: red; font-size:30px; font-family: Verdana, sans-serif;">Questo è il mio paragrafo di testo colorato di rosso<!--con style setto le impostazioni dello stile grafico di una qualsiasi intestazione e sarebbe un comando CSS-->
    <p>Questo è il mio paragrafo di testo</p>
    <h2>Ecco la lista ad elenco puntato di esempio:</h2>
    <ul><!--È l'acronimo di Unordered List-->
        <li>Elemento 1</li>
        <li>Elemento 2</li>
    </ul>
    <h2 style="color:FireBrick;">Ecco la lista ad elenco numerato di esempio:</h2><!--con color cambio il colore del font-->
    <ol style="color:Chocolate;"><!--È l'acronimo di Ordered List-->
        <li>Esempio 1</li>
        <li>Esempio 2</li>
    </ol>
    <h2 style="background-color:orange;">Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
    <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
    <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
    <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
</body>
</html>
<h2>Ecco una immagine inserita dal disco locale senza selezionare la PATH perchè si trova nella stessa cartella (così funziona):</h2>
<img src="R.jpeg" alt="La tua immagine" width="200" height="150"><!--ho scritto direttamente il nome del file senza indicare la PATH perchè essendo dentro la stessa cartella del notebook, inserendo il nome la trova immediatamente-->

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->
#     <title>Il mio titolo</title>
# </head>
# <body style="background-color:powderblue;"><!--con background inserisco uno sfondo--!>
#     <!--Contenuto visibile dalla pagine va qui-->
#     <h1 style="background-color:lightgreen;"Il mio titolo principale</h1>
#     <p style="background-color:tomato;""color: red; font-size:30px; font-family: Verdana, sans-serif;">Questo è il mio paragrafo di testo colorato di rosso<!--con style setto le impostazioni dello stile grafico di una qualsiasi intestazione e sarebbe un comando CSS-->
#     <p>Questo è il mio paragrafo di testo</p>
#     <h2>Ecco la lista ad elenco puntato di esempio:</h2>
#     <ul><!--È l'acronimo di Unordered List-->
#         <li>Elemento 1</li>
#         <li>Elemento 2</li>
#     </ul>
#     <h2 style="color:FireBrick;">Ecco la lista ad elenco numerato di esempio:</h2><!--con color cambio il colore del font-->
#     <ol style="color:Chocolate;"><!--È l'acronimo di Ordered List-->
#         <li>Esempio 1</li>
#         <li>Esempio 2</li>
#     </ol>
#     <h2 style="background-color:orange;">Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
#     <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
#     <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
#     <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
# </body>
# </html>
# <h2>Ecco una immagine inserita dal disco locale senza selezionare la PATH perchè si trova nella stessa cartella (così funziona):</h2>
# <img src="R.jpeg" alt="La tua immagine" width="200" height="150"><!--ho scritto direttamente il nome del file senza indicare la PATH perchè essendo dentro la stessa cartella del notebook, inserendo il nome la trova immediatamente-->

# %%
<!DOCTYPE html>
<html>
<head>
    <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->  
    <title>Il mio titolo</title>
</head>
<body style="background-color:powderblue;"><!--con background inserisco uno sfondo--!>
    <!--Contenuto visibile dalla pagine va qui-->
    <h1 style="background-color:lightgreen;"Il mio titolo principale</h1>
    <p style="background-color:tomato;""color: red; font-size:30px; font-family: Verdana, sans-serif;">Questo è il mio paragrafo di testo colorato di rosso<!--con style setto le impostazioni dello stile grafico di una qualsiasi intestazione e sarebbe un comando CSS-->
    <p>Questo è il mio paragrafo di testo</p>
    <h2 style="font-family:roboto">Ecco la lista ad elenco puntato di esempio (in Roboto):</h2><!--con font-family modifico il tipo di font--->
    <ul style="font-family:roboto"><!--È l'acronimo di Unordered List-->
        <li>Elemento 1</li>
        <li>Elemento 2</li>
    </ul>
    <h2 style="color:FireBrick;font-family:verdana;">Ecco la lista ad elenco numerato di esempio (in Verdana):</h2><!--con color cambio il colore del font e con font-family modifico il tipo di font--->
    <ol style="color:Chocolate;font-family:verdana;"><!--È l'acronimo di Ordered List-->
        <li>Esempio 1</li>
        <li>Esempio 2</li>
    </ol>
    <h2 style="background-color:orange;">Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
    <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
    <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
    <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
</body>
</html>
<h2>Ecco una immagine inserita dal disco locale senza selezionare la PATH perchè si trova nella stessa cartella (così funziona):</h2>
<img src="R.jpeg" alt="La tua immagine" width="200" height="150"><!--ho scritto direttamente il nome del file senza indicare la PATH perchè essendo dentro la stessa cartella del notebook, inserendo il nome la trova immediatamente-->

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <!--I metadati, collegamenti ai fogli di stile, ecc... vanno qui-->
#     <title>Il mio titolo</title>
# </head>
# <body style="background-color:powderblue;"><!--con background inserisco uno sfondo--!>
#     <!--Contenuto visibile dalla pagine va qui-->
#     <h1 style="background-color:lightgreen;"Il mio titolo principale</h1>
#     <p style="background-color:tomato;""color: red; font-size:30px; font-family: Verdana, sans-serif;">Questo è il mio paragrafo di testo colorato di rosso<!--con style setto le impostazioni dello stile grafico di una qualsiasi intestazione e sarebbe un comando CSS-->
#     <p>Questo è il mio paragrafo di testo</p>
#     <h2 style="font-family:roboto">Ecco la lista ad elenco puntato di esempio (in Roboto):</h2><!--con font-family modifico il tipo di font--->
#     <ul style="font-family:roboto"><!--È l'acronimo di Unordered List-->
#         <li>Elemento 1</li>
#         <li>Elemento 2</li>
#     </ul>
#     <h2 style="color:FireBrick;font-family:verdana;">Ecco la lista ad elenco numerato di esempio (in Verdana):</h2><!--con color cambio il colore del font e con font-family modifico il tipo di font--->
#     <ol style="color:Chocolate;font-family:verdana;"><!--È l'acronimo di Ordered List-->
#         <li>Esempio 1</li>
#         <li>Esempio 2</li>
#     </ol>
#     <h2 style="background-color:orange;">Ecco la lista dei collegamenti di esempio:</h2><!--Con il target-->
#     <a href="https://www.istitutofreud.it" target="_blank">https://www.istitutofreud.it</a><br><!--Il br si usa per andare a capo, sarebbe come lo /n in Python-->
#     <a href="https://it.wikipedia.org/wiki/Pagina_principale" target="_blank">https://it.wikipedia.org/wiki/Pagina_principale</a><br>
#     <a href="https://stackoverflow.com/" target="_blank">https://stackoverflow.com/</a><br>
# </body>
# </html>
# <h2>Ecco una immagine inserita dal disco locale senza selezionare la PATH perchè si trova nella stessa cartella (così funziona):</h2>
# <img src="R.jpeg" alt="La tua immagine" width="200" height="150"><!--ho scritto direttamente il nome del file senza indicare la PATH perchè essendo dentro la stessa cartella del notebook, inserendo il nome la trova immediatamente-->

# %% [markdown]
# # LE TABELLE
